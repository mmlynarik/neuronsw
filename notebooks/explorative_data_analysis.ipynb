# %% [markdown]
# #### Imports and setup

# %%
from pathlib import Path

from trams.utils import change_cwd_for_jupyter

change_cwd_for_jupyter()

from trams.datamodule import TramsDataModule
from trams.dataset import print_labels_statistics, print_metadata_statistics
from trams.predict import predict_trams_from_wav, validate
from trams.config import RAW_DATA_DIR_TEST

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### Load wav files into dataset and apply processing steps

# %%
dm = TramsDataModule(batch_size=16, validation_split=0.1, max_length_secs=4, snr=5)
dataset = dm.prepare_data()
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'label', 'sample_rate', 'num_frames', 'num_channels', 'bits_per_sample', 'label_name', 'path', 'spectrogram'],
#         num_rows: 2696
#     })
#     validation: Dataset({
#         features: ['audio', 'label', 'sample_rate', 'num_frames', 'num_channels', 'bits_per_sample', 'label_name', 'path', 'spectrogram'],
#         num_rows: 300
#     })
# })

# %% [markdown]
# #### Check training data labels and metadata statistics

# %% [markdown]
# We can see that labels are not distributed evenly, which may potentially cause accuracy underperformance in several classes.

# %%
print_labels_statistics(dataset["train"])
# Out:
#                                 count
# label_name               label
# Accelerating_1_New       0        444
# Accelerating_2_CKD_Long  1        152
# Accelerating_3_CKD_Short 2         66
# Accelerating_4_Old       3        369
# Braking_1_New            4        343
# Braking_2_CKD_Long       5        129
# Braking_3_CKD_Short      6         56
# Braking_4_Old            7        392
# Negative                 8        745

# %% [markdown]
# As expected, the number of channels, bits per sample and sample rate are all constant throughout the dataset.

# %%
print_metadata_statistics(dataset["train"])
# Out:
#                                           count
# sample_rate bits_per_sample num_channels
# 22050       32              1              2696

# %% [markdown]
# #### Plot histogram of audio lengths in seconds in order to decide on the truncation threshold

# %% [markdown]
# We can see a bimodal distribution of audio lengths due to the double size of negative samples. We will take 4000 ms as the truncation limit and pad zeros randomly before and after signal.

# %%
dataset["train"].set_format("pandas")
sample_rate = int(dataset["train"][0]["sample_rate"])
(dataset["train"]["num_frames"] / sample_rate).plot.hist(backend="plotly")
# Out:
# <div>                            <div id="2db633fc-bd24-4ea6-acd9-e079ac04190c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2db633fc-bd24-4ea6-acd9-e079ac04190c")) {                    Plotly.newPlot(                        "2db633fc-bd24-4ea6-acd9-e079ac04190c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=num_frames\u003cbr\u003evalue=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"num_frames","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"num_frames","offsetgroup":"num_frames","orientation":"v","showlegend":true,"x":[5.124671201814059,4.163492063492064,4.306530612244898,5.523401360544217,3.573922902494331,5.053786848072562,3.0451700680272107,4.5653061224489795,4.2588208616780046,4.31968253968254,3.8022675736961453,5.084399092970521,1.6004081632653062,5.237097505668935,3.346984126984127,3.5619954648526075,4.873378684807256,2.3215873015873014,4.483356009070294,4.575192743764172,2.751519274376417,5.386349206349206,2.968934240362812,4.694739229024943,2.4091609977324264,4.314331065759637,4.730294784580499,4.781904761904762,3.5631292517006803,4.578049886621315,2.0011337868480727,1.488798185941043,3.3203628117913833,3.48702947845805,4.227845804988662,3.2668934240362812,3.286213151927438,2.4788662131519272,3.083718820861678,2.6305668934240365,4.722358276643991,5.026938775510204,4.363401360544218,4.177324263038549,4.518548752834467,4.383219954648526,3.9500226757369616,2.698548752834467,3.312698412698413,2.851156462585034,4.545079365079365,3.441360544217687,4.382358276643991,4.677777777777778,3.5228571428571427,3.5205895691609976,3.6132879818594104,5.331292517006803,4.375918367346939,3.3903401360544216,3.487800453514739,2.953424036281179,2.863764172335601,3.9522448979591838,4.238730158730159,3.9578684807256237,4.251428571428572,4.481224489795919,2.434512471655329,3.186984126984127,3.8725170068027213,5.158820861678005,4.416916099773243,3.5142403628117913,3.7691609977324263,3.4949206349206348,4.825034013605443,3.193786848072562,3.957596371882086,5.3408616780045355,4.778049886621315,2.9091609977324264,2.583265306122449,4.206757369614513,4.647845804988662,2.5149659863945577,5.228707482993197,2.409886621315193,4.2940589569161,1.7654421768707482,5.5154648526077095,4.40281179138322,4.947709750566894,4.511020408163265,2.154920634920635,6.085850340136054,4.286666666666667,6.068979591836735,5.182675736961452,3.1825850340136053,4.726167800453514,4.322721088435374,4.586031746031746,4.999047619047619,4.593333333333334,3.7039909297052156,5.691065759637188,3.770294784580499,4.35718820861678,5.613605442176871,2.2444897959183674,4.2142403628117915,4.085487528344671,4.820770975056689,3.641814058956916,4.384671201814059,2.6044897959183673,4.8402267573696145,4.001133786848072,3.3402267573696145,4.888480725623583,3.608027210884354,4.128843537414966,5.280317460317461,2.682721088435374,4.8960090702947845,2.8457142857142856,4.849160997732426,5.866575963718821,4.125759637188208,4.881224489795918,3.244716553287982,4.460498866213152,2.385215419501134,4.372199546485261,3.8582312925170066,2.829387755102041,4.384988662131519,4.5980498866213155,3.031111111111111,4.03265306122449,3.551201814058957,4.675238095238095,4.943492063492063,6.217913832199547,4.355011337868481,3.052244897959184,3.4803174603174605,3.6839909297052156,3.5917460317460317,3.3000907029478457,4.006303854875283,4.443537414965986,4.712154195011338,4.935102040816327,3.523356009070295,5.104172335600907,5.352879818594104,2.67578231292517,2.8590022675736964,4.036780045351474,4.240816326530612,4.994331065759638,5.278639455782313,3.1529251700680274,5.253151927437642,3.9716099773242632,7.3211791383219955,3.790204081632653,2.422267573696145,3.320861678004535,3.704807256235828 ...

# %% [markdown]
# #### Check Mel Spectrogram shape

# %%
dataset = dataset.with_format("torch")
dataset["train"][0]["spectrogram"].shape
# Out:
# torch.Size([64, 173])

# %% [markdown]
# #### Predict trams on test wav file

# %%
wav_file = RAW_DATA_DIR_TEST / "tram-2018-12-07-15-32-08.wav"
output_csv = Path.cwd() / "output.csv"
predict_trams_from_wav(wav_file, output_csv)
# Out:
# Loaded tram-2018-12-07-15-32-08.wav file spanning 300.0 seconds.
# 8    2960
# dtype: int64

# %%
validate(validation_split=0.1, use_cache=True, max_length_secs=4, snr=5)
# Out:
# Accuracy: 0.917, Total items: 300
